# %%
# Imports
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

print("All imports successful – ready to go!")
# Out:
# All imports successful – ready to go!

# %%
llm = OllamaLLM(model="llama3.1:8b", temperature=0.0)  # zero temp = deterministic reasoning

# %%
# Sentiment + Reasoning function 
def analyze_sentiment(statement: str):
    template = """You are an expert in sentiment analysis and logical reasoning.

Statement: "{statement}"

Step by step:
1. Detect the overall sentiment: Positive, Negative, Neutral, or Mixed.
2. Quote the exact words/phrases that led you to this conclusion.
3. Explain your reasoning clearly in 2–4 sentences.
4. Rate confidence from 1–10.

Respond in this exact format:
Sentiment: [your answer]
Evidence: [quoted phrases]
Reasoning: [your explanation]
Confidence: [1–10]"""

    prompt = ChatPromptTemplate.from_template(template)
    chain = prompt | llm | StrOutputParser()
    return chain.invoke({"statement": statement})

# %%
# Testing the sentiment analysis
statement = "I absolutely love the new iPhone camera, but the battery life is still terrible and the price is insane."

print(analyze_sentiment(statement))
# Out:
# Sentiment: Mixed
# Evidence: "I absolutely love the new iPhone camera, but the battery life is still terrible and the price is insane."
# Reasoning: The statement starts with a strongly positive sentiment ("I absolutely love") towards the iPhone camera, indicating that the speaker has a favorable opinion of its performance. However, this positivity is immediately followed by two negative comments about the battery life and price, which are described as "terrible" and "insane", respectively. This juxtaposition of positive and negative sentiments leads to a mixed overall sentiment.
# Confidence: 9
